# %%
import pandas as pd
import numpy as np
import os, random, math, glob
from IPython.display import Image as IM
from IPython.display import clear_output
import tqdm
from matplotlib import pyplot as plt
# %matplotlib inline
from catboost import CatBoostClassifier
from scipy.sparse import hstack
from sklearn.metrics import roc_auc_score, accuracy_score, log_loss
from tqdm import tqdm_notebook, tqdm
from scipy import stats
from sklearn.model_selection import RepeatedStratifiedKFold, StratifiedKFold, GroupKFold, train_test_split
import re
from sklearn.preprocessing import LabelEncoder
#from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.cluster import KMeans
import lightgbm as lgb
from category_encoders import *
from sklearn.model_selection import KFold
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
plt.rcParams['figure.figsize'] = [5, 5]
pd.set_option('display.max_columns', None)

import numpy as np
import pandas as pd
from sklearn import metrics, preprocessing, model_selection

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sub = pd.read_csv('sample_submission_iA3afxn.csv')

# %%
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
test.head()
# Out:
#        id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110   Male   25                1         11.0                   1
# 1  381111   Male   40                1         28.0                   0
# 2  381112   Male   47                1         28.0                   0
# 3  381113   Male   24                1         27.0                   1
# 4  381114   Male   27                1         28.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No         35786.0                 152.0       53
# 1    1-2 Year            Yes         33762.0                   7.0      111
# 2    1-2 Year            Yes         40050.0                 124.0      199
# 3    < 1 Year            Yes         37356.0                 152.0      187
# 4    < 1 Year             No         59097.0                 152.0      297

# %%
train.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# dtype: int64

# %%
# Checking the Target Variable
train['Response'].value_counts().plot(kind='bar')

# %%
# getting the counts of each customer
for cols in train.columns:
    print('------------------------------------')
    print(train[cols].value_counts())
# Out:
# ------------------------------------
# 2047      1
# 295621    1
# 84604     1
# 82557     1
# 88702     1
#          ..
# 107934    1
# 109983    1
# 21920     1
# 23969     1
# 2049      1
# Name: id, Length: 381109, dtype: int64
# ------------------------------------
# Male      206089
# Female    175020
# Name: Gender, dtype: int64
# ------------------------------------
# 24    25960
# 23    24256
# 22    20964
# 25    20636
# 21    16457
#       ...
# 81       56
# 82       29
# 83       22
# 84       11
# 85       11
# Name: Age, Length: 66, dtype: int64
# ------------------------------------
# 1    380297
# 0       812
# Name: Driving_License, dtype: int64
# ------------------------------------
# 28.0    106415
# 8.0      33877
# 46.0     19749
# 41.0     18263
# 15.0     13308
# 30.0     12191
# 29.0     11065
# 50.0     10243
# 3.0       9251
# 11.0      9232
# 36.0      8797
# 33.0      7654
# 47.0      7436
# 35.0      6942
# 6.0       6280
# 45.0      5605
# 37.0      5501
# 18.0      5153
# 48.0      4681
# 14.0      4678
# 39.0      4644
# 10.0      4374
# 21.0      4266
# 2.0       4038
# 13.0      4036
# 7.0       3279
# 12.0      3198
# 9.0       3101
# 27.0      2823
# 32.0      2787
# 43.0      2639
# 17.0      2617
# 26.0      2587
# 25.0      2503
# 24.0      2415
# 38.0      2026
# 0.0       2021
# 16.0      2007
# 31.0      1960
# 23.0      1960
# 20.0      1935
# 49.0      1832
# 4.0       1801
# 34.0      1664
# 19.0      1535
# 22.0      1309
# 40.0      1295
# 5.0       1279
# 1.0       1008
# 44.0       808
# 42.0       591
# 52.0       267
# 51.0       183
# Name: Region_Code, dtype: int64
# ------------------------------------
# 0    206481
# 1    174628
# Name: Previously_Insured, dtype: int64
# ------------------------------------
# 1-2 Year     200316
# < 1 Year     164786
# > 2 Years     16007
# Name: Vehicle_Age, dtype: int64
# ------------------------------------
# Yes    192413
# No     188696
# Name: Vehicle_Damage, dtype: int64
# ------------------------------------
# 2630.0     64877
# 69856.0      140
# 39008.0       41
# 38287.0       38
# 45179.0       38
#            ...
# 62326.0        1
# 59733.0        1
# 55934.0        1
# 75387.0        1
# 53346.0        1
# Name: Annual_Premium, Length: 48838, dtype: int64
# ------------------------------------
# 152.0    134784
# 26.0      79700
# 124.0     73995
# 160.0     21779
# 156.0     10661
#           ...
# 144.0         1
# 149.0         1
# 84.0          1
# 143.0         1
# 43.0          1
# Name: Policy_Sales_Channel, Length: 155, dtype: int64
# ------------------------------------
# 256    1418
# 73     1410
# 282    1397
# 158    1394
# 187    1392
#        ...
# 205    1235
# 89     1234
# 32     1230
# 224    1227
# 277    1226
# Name: Vintage, Length: 290, dtype: int64
# ------------------------------------
# 0    334399
# 1     46710
# Name: Response, dtype: int64

# %%
print(train.shape)
print(test.shape)
# Out:
# (381109, 12)
# (127037, 11)

# %%
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# map them
train['Vehicle_Age'] = train['Vehicle_Age'].replace({'1-2 Year':1, '< 1 Year':0, '> 2 Years':2})
# map them
test['Vehicle_Age'] = test['Vehicle_Age'].replace({'1-2 Year':1, '< 1 Year':0, '> 2 Years':2})

# %%
train['Vehicle_Damage'] = train['Vehicle_Damage'].map({'Yes':1, 'No':0})
test['Vehicle_Damage'] = test['Vehicle_Damage'].map({'Yes':1, 'No':0})

# %%
train['Gender'] = train['Gender'].astype('category').cat.codes
test['Gender'] = test['Gender'].astype('category').cat.codes

# %%
#train = pd.get_dummies(train, columns=['Gender', 'Vehicle_Damage'])

# %%
#test = pd.get_dummies(test, columns=['Gender', 'Vehicle_Damage'])

# %%
df = train.append(test, ignore_index=True, sort=False)

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
#df = df[['Age', 'Annual_Premium', 'Vintage','Policy_Sales_Channel','id', 'Gender','Region_Code','Response',
   #     'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage','Driving_License']]

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1       1   44                1         28.0                   0
# 1   2       1   76                1          3.0                   0
# 2   3       1   47                1         28.0                   0
# 3   4       1   21                1         11.0                   1
# 4   5       0   29                1         41.0                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0            2               1         40454.0                  26.0      217
# 1            1               0         33536.0                  26.0      183
# 2            2               1         38294.0                  26.0       27
# 3            0               0         28619.0                 152.0      203
# 4            0               0         27496.0                 152.0       39
#
#    Response
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0

# %%
df['Region_Count'] = df['Region_Code'].map(df['Region_Code'].value_counts())
#df['Policy_Sales_Channel_Count'] = df['Policy_Sales_Channel'].map(df['Policy_Sales_Channel'].value_counts())

# %%
df['policy_region'] = df['Policy_Sales_Channel'].astype(str) + '_' + df['Region_Code'].astype(str)

# %%
#df['policy_region'] = df['policy_region'].astype('category').cat.codes

# %%
df['policy_region'] = df['policy_region'].map(df['policy_region'].value_counts())

# %%
def aggregate_functions(df):        
    
    agg_func = {
        'Annual_Premium' : ['min', 'max', 'nunique', 'size','std', 'mean', 'median', 'sum'],
        'Vintage' : ['min', 'max', 'nunique', 'size','std', 'mean', 'median', 'sum'],
        'Region_Count' : ['min', 'max', 'std', 'mean', 'median', 'sum']}
    
    agg_df = df.groupby(['Region_Code']).agg(agg_func)
    agg_df.columns = ['_by_region'.join(col).strip() for col in agg_df.columns.values]
    agg_df.reset_index(inplace=True)
    
    agg_df = pd.merge(df, agg_df, on='Region_Code', how='left')
    
    return agg_df

# %%
df = aggregate_functions(df)

# %%
def aggregate_functions(df):        
    
    agg_func = {
        'Annual_Premium' : ['min', 'max', 'nunique', 'size','std', 'mean', 'median', 'sum'],
        'Vintage' : ['min', 'max', 'nunique', 'size','std', 'mean', 'median', 'sum'],
        'Region_Count' : ['min', 'max', 'std', 'mean', 'median', 'sum']
        }
    
    agg_df = df.groupby(['Policy_Sales_Channel']).agg(agg_func)
    agg_df.columns = ['_by_policy'.join(col).strip() for col in agg_df.columns.values]
    agg_df.reset_index(inplace=True)
    
    agg_df = pd.merge(df, agg_df, on='Policy_Sales_Channel', how='left')
    
    return agg_df

# %%
df = aggregate_functions(df)

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1       1   44                1         28.0                   0
# 1   2       1   76                1          3.0                   0
# 2   3       1   47                1         28.0                   0
# 3   4       1   21                1         11.0                   1
# 4   5       0   29                1         41.0                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0            2               1         40454.0                  26.0      217
# 1            1               0         33536.0                  26.0      183
# 2            2               1         38294.0                  26.0       27
# 3            0               0         28619.0                 152.0      203
# 4            0               0         27496.0                 152.0       39
#
#    Response  Region_Count  policy_region  Annual_Premium_by_regionmin  \
# 0       1.0        141937          50117                       2630.0
# 1       0.0         12349           2240                       2630.0
# 2       1.0        141937          50117                       2630.0
# 3       0.0         12328           6735                       2630.0
# 4       0.0         24400          11503                       2630.0
#
#    Annual_Premium_by_regionmax  Annual_Premium_by_regionnunique  \
# 0                     540165.0                            39411
# 1                     424578.0                             7473
# 2                     540165.0                            39411
# 3                     193637.0                             7705
# 4                     339396.0                            13801
#
#    Annual_Premium_by_regionsize  Annual_Premium_by_regionstd  \
# 0                        141937                 18483.115668
# 1                         12349                 14589.746562
# 2                        141937                 18483.115668
# 3                         12328                 14000.397877
# 4                         24400                 15174.548982
#
#    Annual_Premium_by_regionmean  Annual_Premium_by_regionmedian  \
# 0                  38649.878763                         38717.0
# 1                  24465.445218                         26055.0
# 2                  38649.878763                         38717.0
# 3                  27655.183160                         29099.5
# 4                  30948.979918                         31623.5
#
#    Annual_Premium_by_regionsum  Vintage_by_regionmin  Vintage_by_regionmax  \
# 0                 5.485848e+09                    10                   299
# 1                 3.021238e+08                    10                   299
# 2                 5.485848e+09                    10                   299
# 3                 3.409331e+08                    10                   299
# 4                 7.551551e+08                    10                   299
#
#    Vintage_by_regionnunique  Vintage_by_regionsize  Vintage_by_regionstd  \
# 0                       290                 141937             83.700191
# 1                       290                  12349             82.796075
# 2                       290                 141937             83.700191
# 3                       290                  12328             83.740509
# 4                       290                  24400             83.736493
#
#    Vintage_by_regionmean  Vintage_by_regionmedian  Vintage_by_regionsum  \
# 0             154.266618                    154.0              21896141
# 1             154.864442                    154.0               1912421
# 2             154.266618                    154.0              21896141
# 3             154.520360                    154.0               1904927
# 4             154.851189                    155.0               3778369
#
#    Region_Count_by_regionmin  Region_Count_by_regionmax  \
# 0                     141937                     141937
# 1                      12349                      12349
# 2                     141937                     141937
# 3                      12328                      12328
# 4                      24400                      24400
#
#    Region_Count_by_regionstd  Region_Count_by_regionmean  \
# 0                        0.0                      141937
# 1                        0.0                       12349
# 2                        0.0                      141937
# 3                        0.0                       12328
# 4                        0.0                       24400
#
#    Region_Count_by_regionmedian  Region_Count_by_regionsum  \
# 0                        141937                20146111969
# 1                         12349                  152497801
# 2                        141937                20146111969
# 3                         12328                  151979584
# 4                         24400                  595360000
#
#    Annual_Premium_by_policymin  Annual_Premium_by_policymax  \
# 0                       2630.0                     540165.0
# 1                       2630.0                     540165.0
# 2                       2630.0                     540165.0
# 3                       2630.0                     495106.0
# 4                       2630.0                     495106.0
#
#    Annual_Premium_by_policynunique  Annual_Premium_by_policysize  \
# 0                            35251                        106594
# 1                            35251                        106594
# 2                            35251                        106594
# 3                            38742                        179523
# 4                            38742                        179523
#
#    Annual_Premium_by_policystd  Annual_Premium_by_policymean  \
# 0                 18368.095093                  33639.830863
# 1                 18368.095093                  33639.830863
# 2                 18368.095093                  33639.830863
# 3                 14043.443197                  30898.685511
# 4                 14043.443197                  30898.685511
#
#    Annual_Premium_by_policymedian  Annual_Premium_by_policysum  \
# 0                         34630.0                 3.585804e+09
# 1                         34630.0                 3.585804e+09
# 2                         34630.0                 3.585804e+09
# 3                         30756.0                 5.547025e+09
# 4                         30756.0                 5.547025e+09
#
#    Vintage_by_policymin  Vintage_by_policymax  Vintage_by_policynunique  \
# 0                    10                   299                       290
# 1                    10                   299                       290
# 2                    10                   299                       290
# 3                    10                   299                       290
# 4                    10                   299                       290
#
#    Vintage_by_policysize  Vintage_by_policystd  Vintage_by_policymean  \
# 0                 106594             83.816780             154.405070
# 1                 106594             83.816780             154.405070
# 2                 106594             83.816780             154.405070
# 3                 179523             83.624244             154.624338
# 4                 179523             83.624244             154.624338
#
#    Vintage_by_policymedian  Vintage_by_policysum  Region_Count_by_policymin  \
# 0                    154.0              16458654                        271
# 1                    154.0              16458654                        271
# 2                    154.0              16458654                        271
# 3                    155.0              27758625                        271
# 4                    155.0              27758625                        271
#
#    Region_Count_by_policymax  Region_Count_by_policystd  \
# 0                     141937               63486.388009
# 1                     141937               63486.388009
# 2                     141937               63486.388009
# 3                     141937               40038.624552
# 4                     141937               40038.624552
#
#    Region_Count_by_policymean  Region_Count_by_policymedian  \
# 0                75448.754564                         44900
# 1                75448.754564                         44900
# 2                75448.754564                         44900
# 3                27787.879659                         12349
# 4                27787.879659                         12349
#
#    Region_Count_by_policysum
# 0                 8042384544
# 1                 8042384544
# 2                 8042384544
# 3                 4988563520
# 4                 4988563520

# %%
train = df[df['Response'].isnull()!=True]
test = df[df['Response'].isnull()==True]
test.drop('Response', axis=1, inplace=True)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train['Vintage'].describe()
# Out:
# count    381109.000000
# mean        154.347397
# std          83.671304
# min          10.000000
# 25%          82.000000
# 50%         154.000000
# 75%         227.000000
# max         299.000000
# Name: Vintage, dtype: float64

# %%
train['Vintage'].corr(train['Annual_Premium'])
# Out:
# -0.0006084171513098587

# %%
test_id = test['id']

# %%
train = train.drop('id', axis=1)
test = test.drop('id', axis=1)

# %%
train.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       1   44                1         28.0                   0            2
# 1       1   76                1          3.0                   0            1
# 2       1   47                1         28.0                   0            2
# 3       1   21                1         11.0                   1            0
# 4       0   29                1         41.0                   1            0
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response  \
# 0               1         40454.0                  26.0      217       1.0
# 1               0         33536.0                  26.0      183       0.0
# 2               1         38294.0                  26.0       27       1.0
# 3               0         28619.0                 152.0      203       0.0
# 4               0         27496.0                 152.0       39       0.0
#
#    Region_Count  policy_region  Annual_Premium_by_regionmin  \
# 0        141937          50117                       2630.0
# 1         12349           2240                       2630.0
# 2        141937          50117                       2630.0
# 3         12328           6735                       2630.0
# 4         24400          11503                       2630.0
#
#    Annual_Premium_by_regionmax  Annual_Premium_by_regionnunique  \
# 0                     540165.0                            39411
# 1                     424578.0                             7473
# 2                     540165.0                            39411
# 3                     193637.0                             7705
# 4                     339396.0                            13801
#
#    Annual_Premium_by_regionsize  Annual_Premium_by_regionstd  \
# 0                        141937                 18483.115668
# 1                         12349                 14589.746562
# 2                        141937                 18483.115668
# 3                         12328                 14000.397877
# 4                         24400                 15174.548982
#
#    Annual_Premium_by_regionmean  Annual_Premium_by_regionmedian  \
# 0                  38649.878763                         38717.0
# 1                  24465.445218                         26055.0
# 2                  38649.878763                         38717.0
# 3                  27655.183160                         29099.5
# 4                  30948.979918                         31623.5
#
#    Annual_Premium_by_regionsum  Vintage_by_regionmin  Vintage_by_regionmax  \
# 0                 5.485848e+09                    10                   299
# 1                 3.021238e+08                    10                   299
# 2                 5.485848e+09                    10                   299
# 3                 3.409331e+08                    10                   299
# 4                 7.551551e+08                    10                   299
#
#    Vintage_by_regionnunique  Vintage_by_regionsize  Vintage_by_regionstd  \
# 0                       290                 141937             83.700191
# 1                       290                  12349             82.796075
# 2                       290                 141937             83.700191
# 3                       290                  12328             83.740509
# 4                       290                  24400             83.736493
#
#    Vintage_by_regionmean  Vintage_by_regionmedian  Vintage_by_regionsum  \
# 0             154.266618                    154.0              21896141
# 1             154.864442                    154.0               1912421
# 2             154.266618                    154.0              21896141
# 3             154.520360                    154.0               1904927
# 4             154.851189                    155.0               3778369
#
#    Region_Count_by_regionmin  Region_Count_by_regionmax  \
# 0                     141937                     141937
# 1                      12349                      12349
# 2                     141937                     141937
# 3                      12328                      12328
# 4                      24400                      24400
#
#    Region_Count_by_regionstd  Region_Count_by_regionmean  \
# 0                        0.0                      141937
# 1                        0.0                       12349
# 2                        0.0                      141937
# 3                        0.0                       12328
# 4                        0.0                       24400
#
#    Region_Count_by_regionmedian  Region_Count_by_regionsum  \
# 0                        141937                20146111969
# 1                         12349                  152497801
# 2                        141937                20146111969
# 3                         12328                  151979584
# 4                         24400                  595360000
#
#    Annual_Premium_by_policymin  Annual_Premium_by_policymax  \
# 0                       2630.0                     540165.0
# 1                       2630.0                     540165.0
# 2                       2630.0                     540165.0
# 3                       2630.0                     495106.0
# 4                       2630.0                     495106.0
#
#    Annual_Premium_by_policynunique  Annual_Premium_by_policysize  \
# 0                            35251                        106594
# 1                            35251                        106594
# 2                            35251                        106594
# 3                            38742                        179523
# 4                            38742                        179523
#
#    Annual_Premium_by_policystd  Annual_Premium_by_policymean  \
# 0                 18368.095093                  33639.830863
# 1                 18368.095093                  33639.830863
# 2                 18368.095093                  33639.830863
# 3                 14043.443197                  30898.685511
# 4                 14043.443197                  30898.685511
#
#    Annual_Premium_by_policymedian  Annual_Premium_by_policysum  \
# 0                         34630.0                 3.585804e+09
# 1                         34630.0                 3.585804e+09
# 2                         34630.0                 3.585804e+09
# 3                         30756.0                 5.547025e+09
# 4                         30756.0                 5.547025e+09
#
#    Vintage_by_policymin  Vintage_by_policymax  Vintage_by_policynunique  \
# 0                    10                   299                       290
# 1                    10                   299                       290
# 2                    10                   299                       290
# 3                    10                   299                       290
# 4                    10                   299                       290
#
#    Vintage_by_policysize  Vintage_by_policystd  Vintage_by_policymean  \
# 0                 106594             83.816780             154.405070
# 1                 106594             83.816780             154.405070
# 2                 106594             83.816780             154.405070
# 3                 179523             83.624244             154.624338
# 4                 179523             83.624244             154.624338
#
#    Vintage_by_policymedian  Vintage_by_policysum  Region_Count_by_policymin  \
# 0                    154.0              16458654                        271
# 1                    154.0              16458654                        271
# 2                    154.0              16458654                        271
# 3                    155.0              27758625                        271
# 4                    155.0              27758625                        271
#
#    Region_Count_by_policymax  Region_Count_by_policystd  \
# 0                     141937               63486.388009
# 1                     141937               63486.388009
# 2                     141937               63486.388009
# 3                     141937               40038.624552
# 4                     141937               40038.624552
#
#    Region_Count_by_policymean  Region_Count_by_policymedian  \
# 0                75448.754564                         44900
# 1                75448.754564                         44900
# 2                75448.754564                         44900
# 3                27787.879659                         12349
# 4                27787.879659                         12349
#
#    Region_Count_by_policysum
# 0                 8042384544
# 1                 8042384544
# 2                 8042384544
# 3                 4988563520
# 4                 4988563520

# %%
X = train.drop("Response", axis=1)
y = train["Response"]

# %%
    params = {}
    params["objective"] = "binary"
    params['metric'] = 'auc'
    params["max_depth"] = -1
    params["num_leaves"] = 64
    params["min_data_in_leaf"] = 20
    #params["min_sum_hessian_in_leaf"] = 5
    params["learning_rate"] = 0.03
    params["bagging_fraction"] = 0.9
    params["feature_fraction"] = 0.35
    params["feature_fraction_seed"] = 20
    params["bagging_freq"] = 10
    params["bagging_seed"] = 30
    params["'min_child_weight'"] = 0.09
    params["lambda_l1"] = 0.01
    params["verbosity"] = -1

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,roc_auc_score
errcb=[]
y_pred_totcb=[]
fold=StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
i=1
for train_index, test_index in fold.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    m = LGBMClassifier(**params,n_estimators=3000,reg_alpha=0.3434, reg_lambda=0.732745, colsample_bytree=0.29034,subsample=70,
                      subsample_freq=0.9)
    m.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_test, y_test)],verbose=-1, early_stopping_rounds=100)#,verbose=100)
    preds=m.predict_proba(X_test)[:, 1]
    print("err: ",roc_auc_score(y_test,preds))
    errcb.append(roc_auc_score(y_test,preds))
    p = m.predict_proba(test)[:, 1]
    y_pred_totcb.append(p)
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [281]	training's auc: 0.870989	valid_1's auc: 0.855205
# err:  0.8552053595482254
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [219]	training's auc: 0.869011	valid_1's auc: 0.857005
# err:  0.8570051173431915
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [365]	training's auc: 0.872335	valid_1's auc: 0.86228
# err:  0.8622796742139988
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [262]	training's auc: 0.870195	valid_1's auc: 0.858449
# err:  0.8584491380952819
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [420]	training's auc: 0.873956	valid_1's auc: 0.860933
# err:  0.8609330425233983
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [250]	training's auc: 0.869689	valid_1's auc: 0.858975
# err:  0.8589753540116715
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [227]	training's auc: 0.868938	valid_1's auc: 0.858552
# err:  0.858551780096882
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [327]	training's auc: 0.871874	valid_1's auc: 0.858959
# err:  0.8589592878895435
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [344]	training's auc: 0.872047	valid_1's auc: 0.859965
# err:  0.8599648754044859
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [227]	training's auc: 0.869012	valid_1's auc: 0.859315
# err:  0.8593147295328145

# %%
np.mean(errcb)
# Out:
# 0.8589638358659493

# %%
d = {"id": test_id, 'Response': np.mean(y_pred_totcb, 0)}
test_predictions = pd.DataFrame(data=d)
subs = test_predictions[["id", 'Response']].round(4)

# %%
#subs['Response'] = subs['Response'].rank()

# %%
subs.to_csv('lgb23.csv', index=False)

# %%
subs.head()
# Out:
#             id  Response
# 381109  381110    0.0020
# 381110  381111    0.3392
# 381111  381112    0.2915
# 381112  381113    0.0123
# 381113  381114    0.0018

# %%
subs['Response'].isnull().sum()
# Out:
# 0

# %%
fea_imp = pd.DataFrame({'imp':m.feature_importances_, 'col': X.columns})
fea_imp = fea_imp.sort_values(['imp', 'col'], ascending=[True, False]).iloc[-40:]
_ = fea_imp.plot(kind='barh', x='col', y='imp', figsize=(20, 10))
plt.savefig('catboost_feature_importance.png')

# %%
a = pd.read_csv('cat6.csv')
b = pd.read_csv('lgb23.csv')
c = pd.read_csv('sub10.csv')

# %%
#(0.46 * a['Response'] + 0.54 * b['Response']).round(3)

# %%
a['Response'] = (0.46 * a['Response'] + 0.54 * b['Response']).round(3)

# %%
a['Response'] = (0.8 * a['Response'] + 0.2 * c['Response']).round(3)

# %%
a.to_csv('stack14.csv', index=False)
